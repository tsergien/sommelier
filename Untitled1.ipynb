# %%
#V.1

from matplotlib import pyplot as plt
import pandas as pd

# You are allowed to import and use the matplotlib, pandas, and the standard python
# libraries for this project.

# ◦ You are NOT allowed to use pandas DataFrame math/matrix methods (i.e.
# ‘.T’, ‘.transpose’, ‘.dot’, ‘.add’, ‘.divide’, ‘.mean’, ‘.std’, etc. . . )

# • You are NOT allowed to directly import and use libraries like: numpy, scipy, scikitlearn, tensorflow, etc


white_df = pd.read_csv("resources/winequality-white.csv", sep=";")
red_df = pd.read_csv("resources/winequality-red.csv", sep=";") 

print(red_df.columns)


def plot_scatter_matrix(wine_data, good_threshold, bad_threshold, save_plot=False):
    assert good_threshold > bad_threshold, "Please, enter good_treshold sctrictly > than bad_treshold"
    q = wine_data['quality']    

    labels = wine_data.columns[:-1]
    f, axarr = plt.subplots(wine_data.shape[1]-1, wine_data.shape[1]-1, figsize=(20, 20))
    f.suptitle('Dependence between acidity and quality')
    f.subplots_adjust(wspace=0, hspace=0)

    k = 0
    for x in [wine_data[label] for label in labels]:
        j = 0
        for y in [wine_data[label] for label in labels]:
            axarr[k][j].set_xticks([])
            axarr[k][j].set_yticks([])
            if k == j:
                axarr[k][j].text(0.1, 0.5, labels[k], fontsize=11)
            else:
                colors = [('orchid' if q[i]<= bad_threshold else ('green' if q[i]>=good_threshold else 'None'))\
                          for i in range(wine_data.shape[0])]
                axarr[k][j].scatter(x, y, marker='.', c=colors)
            j+=1
        k+=1
    plt.savefig('fig.png') if save_plot else _
    
        
    
plot_scatter_matrix(red_df, 8, 3, True)
plot_scatter_matrix(white_df, 6, 5)

# Important chemical factors: volatile acidity, sulfates, alcohol. 
# Basically we can divide almost strictly bad and good wines considering them.
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# V.2

import random
random.seed(777)

def error(y: list, d: list, n: int) -> float:
    return n * sum([abs(d[i] - y[i]) for i in range(n)])

def f(factors: list, weights: list) -> float:
    return sum(factors[i] * weights[i] for i in range(len(factors)-1))

def perceptron(wine_data, threshold):
    learning_rate = 0.1
    factors_len = wine_data.shape[1]-1
    data_len = wine_data.shape[0]
    w = [random.random() for i in range(factors_len)]
    y = [0 for _ in range(data_len)]
    d = wine_data['quality'] >= threshold
    
    error_ = error(y, d, data_len)
    while error_ > 1:
        print(f'error = {error_}')
        for j in range(data_len): # for each row in data
#             print(f'j = {j}, error = {error_}')
            factors = wine_data.iloc[j]
            y[j] = int(sum([w[i] * factors[i] for i in range(factors_len)]) >= threshold)
            for i in range(factors_len):
                w[i] += learning_rate * (d[j] - y[j]) * factors[i]
#             print(f'weights = {w}')
    error_ = error(y, d, data_len)
    
    print(f'weights: {w}')
    print(f'error: {f(factors, w)}')
    return w
    
    

perceptron(red_df, 6)
# Out:
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# error = 1367145
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-44c098c8e95d> in <module>
#      36
#      37
# ---> 38 perceptron(red_df, 6)
#
# <ipython-input-34-44c098c8e95d> in perceptron(wine_data, threshold)
#      24 #             print(f'j = {j}, error = {error_}')
#      25             factors = wine_data.iloc[j]
# ---> 26             y[j] = int(sum([w[i] * factors[i] for i in range(factors_len)]) >= threshold)
#      27             for i in range(factors_len):
#      28                 w[i] += learning_rate * (d[j] - y[j]) * factors[i]
#
# <ipython-input-34-44c098c8e95d> in <listcomp>(.0)
#      24 #             print(f'j = {j}, error = {error_}')
#      25             factors = wine_data.iloc[j]
# ---> 26             y[j] = int(sum([w[i] * factors[i] for i in range(factors_len)]) >= threshold)
#      27             for i in range(factors_len):
#      28                 w[i] += learning_rate * (d[j] - y[j]) * factors[i]
#
# ~/reps/sommelier/myenv/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/reps/sommelier/myenv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4367                     return s[key]
#    4368
# -> 4369         s = com.values_from_object(series)
#    4370         k = com.values_from_object(key)
#    4371
#
# pandas/_libs/lib.pyx in pandas._libs.lib.values_from_object()
#
# ~/reps/sommelier/myenv/lib/python3.6/site-packages/pandas/core/series.py in get_values(self)
#     492         Same as values (but handles sparseness conversions); is a view.
#     493         """
# --> 494         return self._data.get_values()
#     495
#     496     @property
#
# ~/reps/sommelier/myenv/lib/python3.6/site-packages/pandas/core/internals/managers.py in get_values(self)
#    1556     def get_values(self):
#    1557         """ return a dense type view """
# -> 1558         return np.array(self._block.to_dense(), copy=False)
#    1559
#    1560     @property
#
# ~/reps/sommelier/myenv/lib/python3.6/site-packages/pandas/core/internals/blocks.py in to_dense(self)
#     183
#     184     def to_dense(self):
# --> 185         return self.values.view()
#     186
#     187     @property
#
# KeyboardInterrupt:
